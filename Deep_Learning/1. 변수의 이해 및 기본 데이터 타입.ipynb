# %% [markdown]
# ## 파이썬 언어 기초 지식

# %% [markdown]
# #### 대입연산자 (=), 비교연산자(==)
#   - 대입 연산자의 오른쪽 수식 혹은 값이고, 왼쪽은 변수이다.
#   - 오른쪽의 수식을 계산하고 왼쪽의 변수에 대입한다.
#   - 비교연산자는 좌우의 값이 동일한지 여부를 확인한다.

# %%
a = 10 # 10을 a에 대입하다
b = 5  # 5를 b에 대입하다
a == b # a와 b가 같은지 비교하다) 결과는 True/False으로 나타난다
# Out:
# False

# %% [markdown]
# ### comment(주석)
#    - 같은 줄에서 #뒤로는 실행이 되지 않는다

# %%
a = 10 # 여기는 실행이 되지 않는다
b = 5  # 여기는 실행이 되지 않는다
a == b
'''
c = a*b
d = c*a
'''
# Out:
# '\nc = a*b\nd = c*a\n'

# %% [markdown]
# ### print() 함수
#    - print 함수는 변수의 값을 출력한다
#    - ,로 변수를 나눠서 출력한다
#    - print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)으로 이루어져 있다
#    - sep : 구분자이며, 각 출력할 변수 사이에서 구별하는 역할을 함. 기본적으로 띄어쓰기로 default 된다.
#    - end : 마지막에 출력할 문자열을 가리킨다

# %%
a = 10 # int
b = 11.4 #float
print(a,b)
print(a,10,200,b, sep="*", end="!!",flush=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9ee70854fd92> in <module>()
#       1 a = 10 # int
#       2 b = 11.4 #float
# ----> 3 print(a,b)
#       4 print(a,10,200,b, sep="*", end="!!",flush=False)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### reserved keywords (예약어)
#    - 파이썬이 미리 선정해둔 단어.
#    - 예) print, class, int 등등.
#    - 예약어를 변수로 사용할 수 없다.

# %% [markdown]
# ### 기본 데이터 타입
#   - 정수 (int)
#   - 실수 (float)
#   - 문자열 (str)
#   - 불리언 (boolean)
#   변수의 기본 테이터 타입을 알고 싶으면 type() 함수를 사용하면 된다.

# %%
a = 10
b = 11.2
c ='stop it man'
d = True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### None
#    - 변수가 아무런 값을 갖지 않는다의 의미이다
#    - 일반적으로 변수에 None로 초기화해서 사용한다
#    - 기타 언어의 NULL, nil등과 같은 의미로 사용

# %%
z = None
print(z)
print(type(z))
z = "Hi there"

print(z)
print(type(z))
# Out:
# None
# <class 'NoneType'>
# Hi there
# <class 'str'>

# %% [markdown]
# ### comparison operator(비교 연산자)
#    - 같다 (==)
#    - 같지 않다 (!=)
#    - 크다, 작다 (>, <)
#    - 작거나 같다, 크거나 같다 (>=, <=)
#    - 결과값은 True/False인 boolean 형태이다

# %%
a = 5
b = 4
print(a,b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)

c = a > b
print(type(c))
print(c)

print(a+b)
print(a*b)
print(a-b)
print(a/b)
print(a%b)
print(a**b)
print((a+b)*4) #연산자 우선순위는 스킵~~~
# Out:
# 5 4
# True
# False
# True
# False
# False
# True
# <class 'bool'>
# True
# 9
# 20
# 1
# 1.25
# 1
# 625
# 36

# %%
x = 2
y = 1.5
m = x*y
v = str(m)+"5"
print(m)
print(type(m))
print(v)
print(type(v))
# Out:
# 3.0
# <class 'float'>
# 3.05
# <class 'str'>
